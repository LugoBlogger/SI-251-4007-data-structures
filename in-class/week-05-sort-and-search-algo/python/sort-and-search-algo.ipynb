# %% [markdown]
# Logs
# - [2026/03/26]
#   Section 4.1 from (Sedgewich et al., 2015)

# %%
###

# %% [markdown]
# Run `twentyquestions.py` in terminal. Rememer to set up your Python environment
# before running it
