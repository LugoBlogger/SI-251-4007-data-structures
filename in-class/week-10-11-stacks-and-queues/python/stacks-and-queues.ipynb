# %% [markdown]
# Logs
# - [2026/04/05]
#   Section 4.3 from (Sedgwick et al., 2015)

# %%
import time
import numpy as np

# %% [markdown]
# ### Pushdown stacks

# %% [markdown]
# ### Python list (resizing array) implementation of a stack

# %% [markdown]
# Test if it is faster to insert new item at the end of a stack (a list)
# than at the start of a stack

# %%
rng = np.random.default_rng()
arr = rng.integers(1_000_000, size=200_000)

# %%
# push an item to the stack at the end of a stack (list)
start_t = time.perf_counter()

b = []
for val in arr:
  b.insert(-1, val)

comp_t = time.perf_counter() - start_t
comp_t
# Out:
# 0.043925087000388885

# %%
# push an item to the stack at the beginning of a stack (list)
# comp_time: 
start_t = time.perf_counter()

b = []
for val in arr:
  b.insert(0, val)

comp_t = time.perf_counter() - start_t
comp_t
# Out:
# 7.3311725330022455

# %%
# %run program/arraystack data/tobe.txt
# Out:
# to be not that or be

# %% [markdown]
# ### Linked-list implementation of a stack

# %%
# %run program/linkedstack data/tobe.txt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/Documents/job-related/024 - SI ITK/ITK/Courses/SI-251-4007-data-structures/SI-251-4007-data-structures-github/in-class/week-10-11-stacks-and-queues/python/program/linkedstack.py:40
#      37       print(f"{stack.pop} ", end="")
#      38   print()
# ---> 40 if __name__ == "__main__": _main()
#
# File ~/Documents/job-related/024 - SI ITK/ITK/Courses/SI-251-4007-data-structures/SI-251-4007-data-structures-github/in-class/week-10-11-stacks-and-queues/python/program/linkedstack.py:27, in _main()
#      25 def _main():
#      26   stack = Stack()
# ---> 27   filename = sys.argv[1]
#      28   with open(filename, "r") as fp:
#      29     data = fp.readlines()
#
# NameError: name 'sys' is not defined
