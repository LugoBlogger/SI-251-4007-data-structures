# %% [markdown]
# Logs
# - [2026/03/13]
#   All codes from (Sedgewick et al., 2015): Section 3.2
#
# - [2026/03/18]
#   Using matplotlib, and add method `.draw()` make your plotting program
#   run so fast. In every example, we have to add `.draw()` after we
#   are done in processing of turtle's lines
#
# TODO:

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import charge
import turtle

# %%
seed = 26_03_17
rng = np.random.default_rng(seed)
rng
# Out:
# Generator(PCG64) at 0x7F7A95C8DB60

# %% [markdown]
# ### Basic elements of a data type

# %% [markdown]
# - API

# %% [markdown]
# - Class

# %% [markdown]
# See the `class.py`

# %%
# %run charge.py .5 .5
# Out:
# 21.3 at (0.51, 0.63)
# 1468638248194.164

# %% [markdown]
# - Constructor

# %% [markdown]
# - Instance variables

# %% [markdown]
# - Details of object creation

# %% [markdown]
# - Methods

# %% [markdown]
# - Variable within methods

# %% [markdown]
# - Methods are functions

# %% [markdown]
# - Built-in functionsm

# %% [markdown]
# - Privacy

# %% [markdown]
# ### Stopwatch

# %%
# %run stopwatch 1_000_000
# Out:
# 1.0
# 1.3020754269667671

# %% [markdown]
# ### Histogram

# %%
# %run histogram 50 .5 100_000

# %% [markdown]
# ### Turtle graphics

# %%
# %run turtle 3
# %run turtle 7
# %run turtle 1_000

# %% [markdown]
# - Recursive graphics

# %%
# %run koch 0
# %run koch 1
# %run koch 2
# %run koch 3
# %run koch 4     
# %run koch 5

# %% [markdown]
# - Spiral mirabilis

# %%
# %run spiral 3 1 1.0
# %run spiral 3 10 1.2
# %run spiral 1440 10 1.00004 
# %run spiral 1440 10 1.0004

# %% [markdown]
# - Brownian motion

# %%
# %run drunk 10_000 0.01

# %%
# %run drunks 20 500 .005    #
# %run drunks 20 1000 .005
# %run drunks 20 5000 .005    # 3 secs

# %% [markdown]
# ### Complex numbers

# %% [markdown]
# The basic properties of complex numbers
# 1. Addition: $(x + y\mathbb{i}) + (v + wi) = (x + v) + (y + w)i $
# 2. Multiplication: $(x + yi) * (v + wi) = (xv - yw)+ (yv + xw) i$
# 3. Magnitude: $|x + yi| = \sqrt{x^2 + y^2}$
# 4. Real part: $\operatorname{\mathrm{Re}}(x + yi) = x$
# 5. Imaginarty part: $\operatorname{\mathrm{Im}}(x + yi) = y$

# %% [markdown]
# - Special methods

# %% [markdown]
# - Accessing instance variables in objects of this type

# %% [markdown]
# - Immutability

# %%
# %run complex
# Out:
# -7.0 + 7.0i

# %% [markdown]
# ### Mandelbrot set

# %% [markdown]
# ### Commercial data processing

# %% [markdown]
# - File format

# %% [markdown]
# - Data structure
