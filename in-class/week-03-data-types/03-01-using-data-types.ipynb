# %% [markdown]
# Logs
# - [2026/03/11]
#   All codes from (Sedgwick et al., 2015): Chapter 3

# %% [markdown]
# ### Methods

# %% [markdown]
# ### String processing

# %% [markdown]
# ### Applications of string processing: genomics

# %% [markdown]
# ### A user-defined data type

# %% [markdown]
# ### Color

# %% [markdown]
# ### Digital image processing

# %% [markdown]
# ### Memory management
