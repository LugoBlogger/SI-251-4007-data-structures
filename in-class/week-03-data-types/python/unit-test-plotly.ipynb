# %% [markdown]
# Logs
# - [2026/03/16]
#   Testing plotly

# %%
import numpy as np
import plotly
import plotly.graph_objects as go
import plotly.io as pio

from PIL import Image

# %%
plotly.__version__
# Out:
# '6.0.1'

# %% [markdown]
# Make a plot of a black plot (512px x 512px), and
# load an image

# %%
# img_rgb = np.array([
#   [[255,   0,   0],
#    [  0, 255,   0],
#    [  0,   0, 255]],

#   [[  0, 255,   0],
#    [  0,   0, 255],
#    [255,   0,   0]]
# ], dtype=np.uint8)

_DEFAULT_WIDTH = 512
_DEFAULT_HEIGHT = 512

image_path = "./japan-shiba-inu-512px.jpg"
image = Image.open(image_path)

# img_rgb = np.zeros((_DEFAULT_HEIGHT, _DEFAULT_WIDTH, 3))
img_rgb = np.array(image)

config = {

}

fig = go.Figure(go.Image(z=img_rgb))


fig.update_layout(
  autosize=False,
  xaxis=dict(tickfont_size=20, side="top"),
  yaxis=dict(tickfont_size=20)
)

fig.show()

pio.write_image(fig, "saved-shiba-inu.jpg")

# %%
dir(fig)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_annotation_like',
#  '_allow_disable_validation',
#  '_animation_duration_validator',
#  '_animation_easing_validator',
#  '_batch_layout_edits',
#  '_batch_trace_edits',
#  '_bracket_re',
#  '_build_dispatch_plan',
#  '_build_update_params_from_batch',
#  '_config',
#  '_data',
#  '_data_defaults',
#  '_data_objs',
#  '_data_validator',
#  '_dispatch_layout_change_callbacks',
#  '_dispatch_trace_change_callbacks',
#  '_filter_by_selector',
#  '_frame_objs',
# ...

# %% [markdown]
# Get the size of the image

# %%
fig.data[0].z.shape
# Out:
# (512, 512, 3)

# %% [markdown]
# Get the pixel color at specific coordinate

# %%
a = fig.data[0].z[0, 3]
display(a)

def get_color(c1, c2, c3):
  print(c1, c2, c3)

get_color(*a)
# Out:
# array([98, 77, 72], dtype=uint8)
# 98 77 72

# %% [markdown]
# Set the pixel color at specific point

# %%
fig.data[0].z[200:210, :, :] = [0, 0, 0]
fig.show()

# %% [markdown]
# Simulate turtle graphic

# %%
x_data = []

fig = go.Figure(data=[go.Scatter(x=x_data)])
